# %%
#Import required libraries
import pandas as pd
import json
import requests

# %%
api_url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01"
r = requests.get(api_url)
header = r.headers
print(r.headers)
data = r.json()
# Out:
# {'Date': 'Thu, 19 May 2022 17:43:01 GMT', 'X-Clv-Request-Id': '2b2b7c6f-25c8-4c35-aa52-0ca925b7eb5f', 'Server': 'Cleversafe', 'X-Clv-S3-Version': '2.5', 'Accept-Ranges': 'bytes', 'x-amz-request-id': '2b2b7c6f-25c8-4c35-aa52-0ca925b7eb5f', 'x-amz-mp-parts-count': '2', 'Cache-Control': 'max-age=0,public', 'ETag': '"444164853f0b0dc867ee9cbec13ef254-2"', 'Content-Type': 'application/json', 'Last-Modified': 'Tue, 05 Apr 2022 11:41:34 GMT', 'Content-Length': '12878382'}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    Id                                          Job Title  \
# 0   0                              Digital Media Planner
# 1   1                           Online Bidding Executive
# 2   2  Trainee Research/ Research Executive- Hi- Tech...
# 3   3                                  Technical Support
# 4   4                  Software Test Engineer -hyderabad
#
#   Job Experience Required                                         Key Skills  \
# 0              5 - 10 yrs                      Media Planning| Digital Media
# 1               2 - 5 yrs  pre sales| closing| software knowledge| client...
# 2               0 - 1 yrs  Computer science| Fabrication| Quality check| ...
# 3               0 - 5 yrs                                  Technical Support
# 4               2 - 5 yrs  manual testing| test engineering| test cases| ...
#
#                                 Role Category       Location  \
# 0                                 Advertising    Los Angeles
# 1                                Retail Sales       New York
# 2                                         R&D  San Francisco
# 3  Admin/Maintenance/Security/Datawarehousing  Washington DC
# 4                        Programming & Design         Boston
#
#                                      Functional Area  \
# 0  Marketing , Advertising , MR , PR , Media Plan...
# 1              Sales , Retail , Business Development
# 2                           Engineering Design , R&D
# 3  IT Software - Application Programming , Mainte...
# 4                         IT Software - QA & Testing
#
#                                 Industry                              Role
# 0  Advertising, PR, MR, Event Management  Media Planning Executive/Manager
# 1         IT-Software, Software Services           Sales Executive/Officer
# 2                  Recruitment, Staffing                     R&D Executive
# 3         IT-Software, Software Services        Technical Support Engineer
# 4         IT-Software, Software Services                  Testing Engineer

# %%
df.describe()
# Out:
#                  Id
# count  27005.000000
# mean   14973.294316
# std     8661.945426
# min        0.000000
# 25%     7474.000000
# 50%    14913.000000
# 75%    22477.000000
# max    29999.000000

# %%
df[df['Job Title'] == 'Python']
# Out:
#           Id Job Title Job Experience Required  \
# 0          0    Python              5 - 10 yrs
# 1          1    Python               2 - 5 yrs
# 2          2    Python               0 - 1 yrs
# 3          3    Python               0 - 5 yrs
# 4          4    Python               2 - 5 yrs
# ...      ...       ...                     ...
# 27000  29995    Python              9 - 12 yrs
# 27001  29996    Python               1 - 5 yrs
# 27002  29997    Python               4 - 6 yrs
# 27003  29998    Python              5 - 10 yrs
# 27004  29999    Python               2 - 7 yrs
#
#                                               Key Skills  \
# 0                          Media Planning| Digital Media
# 1      pre sales| closing| software knowledge| client...
# 2      Computer science| Fabrication| Quality check| ...
# 3                                      Technical Support
# 4      manual testing| test engineering| test cases| ...
# ...                                                  ...
# 27000  Graphics| C++| USB| Project management| SOC| F...
# 27001  Service delivery| LMS| CRE| Integration servic...
# 27002      Counselor| Mentor| Trainer| Advisor| Teaching
# 27003  Security Analysis| Software Development Life C...
# 27004  Press release| Public relations| Publishing| W...
#
#                                     Role Category       Location  \
# 0                                     Advertising    Los Angeles
# 1                                    Retail Sales       New York
# 2                                             R&D  San Francisco
# 3      Admin/Maintenance/Security/Datawarehousing  Washington DC
# 4                            Programming & Design         Boston
# ...                                           ...            ...
# 27000                        Programming & Design        Detroit
# 27001                                  Operations        Detroit
# 27002                            University Level        Detroit
# 27003                        Programming & Design        Detroit
# 27004                    Online/Digital Marketing        Detroit
#
#                                          Functional Area  \
# 0      Marketing , Advertising , MR , PR , Media Plan...
# 1                  Sales , Retail , Business Development
# 2                               Engineering Design , R&D
# 3      IT Software - Application Programming , Mainte...
# 4                             IT Software - QA & Testing
# ...                                                  ...
# 27000  IT Software - Embedded , EDA , VLSI , ASIC , C...
# 27001  ITES , BPO , KPO , LPO , Customer Service , Op...
# 27002      Teaching , Education , Training , Counselling
# 27003  IT Software - Application Programming , Mainte...
# 27004  Marketing , Advertising , MR , PR , Media Plan...
#
#                                     Industry  \
# 0      Advertising, PR, MR, Event Management
# 1             IT-Software, Software Services
# 2                      Recruitment, Staffing
# 3             IT-Software, Software Services
# 4             IT-Software, Software Services
# ...                                      ...
# 27000            Semiconductors, Electronics
# 27001          Education, Teaching, Training
# 27002          Education, Teaching, Training
# 27003         IT-Software, Software Services
# 27004         IT-Software, Software Services
#
#                                              Role
# 0                Media Planning Executive/Manager
# 1                         Sales Executive/Officer
# 2                                   R&D Executive
# 3                      Technical Support Engineer
# 4                                Testing Engineer
# ...                                           ...
# 27000                          Software Developer
# 27001                          Operations Manager
# 27002                          Lecturer/Professor
# 27003                          Software Developer
# 27004  Search Engine Optimisation /SEO Specialist
#
# [27005 rows x 9 columns]

# %%
def get_number_of_jobs_T(job):
    number_of_jobs = 0
    #your code goes here
    page=1
    new_results=1
    while new_results>0:
        payload={"description":job,"page":page}
        r=requests.get(api_url,payload)
        new_results =len(r.json())
        page+=1
        number_of_jobs+=(len(r.json()))
    #your code goes here
    return job,number_of_jobs

# %%
df[df['Location'] == 'Washington DC']
# Out:
#           Id Job Title Job Experience Required  \
# 3          3    Python               0 - 5 yrs
# 13        13    Python             3 - 7 Years
# 14        14    Python               2 - 4 yrs
# 15        16    Python               2 - 7 yrs
# 16        17    Python               3 - 7 yrs
# ...      ...       ...                     ...
# 19989  22185    Python               2 - 6 yrs
# 19990  22186    Python               0 - 5 yrs
# 19991  22187    Python               2 - 3 yrs
# 19992  22188    Python               3 - 5 yrs
# 19993  22190    Python              5 - 10 yrs
#
#                                               Key Skills  \
# 3                                      Technical Support
# 13                                   Oracle IDAM|OIM|OAM
# 14     digital marketing| seo| social media marketing...
# 15     Help Desk| Customer Service| customer relation...
# 16     Report Generation| Policies| analytical| proce...
# ...                                                  ...
# 19989  inside sales| team leading| Relationship Manag...
# 19990  upselling| Inbound Sales| csr| International C...
# 19991  Sales Executive Activities| Selling| MS Office...
# 19992  Photoshop| Illustrator| Design| AutoCAD| 3D| A...
# 19993  UI| Javascript| HTML| CSS| AngularJS| React.js...
#
#                                     Role Category       Location  \
# 3      Admin/Maintenance/Security/Datawarehousing  Washington DC
# 13                           Programming & Design  Washington DC
# 14                       Online/Digital Marketing  Washington DC
# 15                             Engineering Design  Washington DC
# 16                                       Accounts  Washington DC
# ...                                           ...            ...
# 19989                                   Pre Sales  Washington DC
# 19990                                       Voice  Washington DC
# 19991        Production/Manufacturing/Maintenance  Washington DC
# 19992                          Engineering Design  Washington DC
# 19993                        Programming & Design  Washington DC
#
#                                          Functional Area  \
# 3      IT Software - Application Programming , Mainte...
# 13     IT Software - Application Programming , Mainte...
# 14     Marketing , Advertising , MR , PR , Media Plan...
# 15                              Engineering Design , R&D
# 16     Accounts , Finance , Tax , Company Secretary ,...
# ...                                                  ...
# 19989              Sales , Retail , Business Development
# 19990  ITES , BPO , KPO , LPO , Customer Service , Op...
# 19991           Production , Manufacturing , Maintenance
# 19992                           Engineering Design , R&D
# 19993  IT Software - Application Programming , Mainte...
#
#                                     Industry  \
# 3             IT-Software, Software Services
# 13           IT-Software / Software Services
# 14     Advertising, PR, MR, Event Management
# 15      Industrial Products, Heavy Machinery
# 16            IT-Software, Software Services
# ...                                      ...
# 19989   Banking, Financial Services, Broking
# 19990                 BPO, Call Centre, ITeS
# 19991   Industrial Products, Heavy Machinery
# 19992  Advertising, PR, MR, Event Management
# 19993         IT-Software, Software Services
#
#                                              Role
# 3                      Technical Support Engineer
# 13                             Software Developer
# 14                 Social Media Marketing Manager
# 15                         Senior Design Engineer
# 16                               Accounts Manager
# ...                                           ...
# 19989                        Pre Sales Consultant
# 19990  Associate/Senior Associate -(NonTechnical)
# 19991                         Industrial Engineer
# 19992                             Design Engineer
# 19993                          Software Developer
#
# [5316 rows x 9 columns]

# %%
get_number_of_jobs_T("python")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-7171711b03ed> in <module>
# ----> 1 get_number_of_jobs_T("python")
#
# <ipython-input-20-02541e19a8e7> in get_number_of_jobs_T(job)
#       6     while new_results>0:
#       7         payload={"description":job,"page":page}
# ----> 8         r=requests.get(api_url,payload)
#       9         new_results =len(r.json())
#      10         page+=1
#
# ~\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     685
#     686         if not stream:
# --> 687             r.content
#     688
#     689         return r
#
# ~\Anaconda\lib\site-packages\requests\models.py in content(self)
#     836                 self._content = None
#     837             else:
# --> 838                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     839
#     840         self._content_consumed = True
#
# ~\Anaconda\lib\site-packages\requests\models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# ~\Anaconda\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# ~\Anaconda\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\Anaconda\lib\http\client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~\Anaconda\lib\http\client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\Anaconda\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\Anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import xlsxwriter

# %%
excel_file_path = r'C:\Users\wbouley\Desktop\Portfolio\Coursera\IBM Data Analysis Professional Certificate\Capstone\week 1/Jobs_API.xlsx'
writer = pd.ExcelWriter(excel_file_path, engine='xlsxwriter')
df.to_excel(writer, index=False, sheet_name='Jobs_API')
writer.save()

# %%
df2 = df.groupby(['Location']).count()
df2
# Out:
#                  Id  Job Title  Job Experience Required  Key Skills  \
# Location
# Austin          434        434                      434         434
# Baltimore      1263       1263                     1263        1263
# Boston         2966       2966                     2966        2966
# Dallas         1208       1208                     1208        1208
# Detroit        3945       3945                     3945        3945
# Houston        3339       3339                     3339        3339
# Los Angeles     640        640                      640         640
# New Orleons     817        817                      817         817
# New York       3226       3226                     3226        3226
# Philadelphia     41         41                       41          41
# San Francisco   435        435                      435         435
# Seattle        3375       3375                     3375        3375
# Washington DC  5316       5316                     5316        5316
#
#                Role Category  Functional Area  Industry  Role
# Location
# Austin                   434              434       434   434
# Baltimore               1263             1263      1263  1263
# Boston                  2966             2966      2966  2966
# Dallas                  1208             1208      1208  1208
# Detroit                 3945             3945      3945  3945
# Houston                 3339             3339      3339  3339
# Los Angeles              640              640       640   640
# New Orleons              817              817       817   817
# New York                3226             3226      3226  3226
# Philadelphia              41               41        41    41
# San Francisco            435              435       435   435
# Seattle                 3375             3375      3375  3375
# Washington DC           5316             5316      5316  5316
