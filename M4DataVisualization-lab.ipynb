# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Visualize the distribution of data.
#
# *   Visualize the relationship between two features.
#
# *   Visualize composition of data.
#
# *   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2022-05-25 16:18:29--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  30.1MB/s    in 1.2s
#
# 2022-05-25 16:18:30 (30.1 MB/s) - ‘m4_survey_data.sqlite’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_sql('Select * from master', conn)
df.head()
# Out:
#    index  Respondent                      MainBranch Hobbyist  \
# 0      0           4  I am a developer by profession       No
# 1      1           9  I am a developer by profession      Yes
# 2      2          13  I am a developer by profession      Yes
# 3      3          16  I am a developer by profession      Yes
# 4      4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
plt.figure(figsize=(10,6))
x = df['ConvertedComp']
plt.hist(x, density=True, bins=30)
# Out:
# (array([8.51634852e-06, 4.23549424e-06, 9.39803440e-07, 2.04120204e-07,
#         7.22925723e-08, 6.09525610e-08, 6.23700624e-08, 4.39425439e-08,
#         5.67000567e-08, 7.51275751e-08, 5.10300510e-08, 5.10300510e-08,
#         6.09525610e-08, 1.84275184e-08, 2.09790210e-07, 5.67000567e-09,
#         1.55925156e-08, 1.55925156e-08, 2.26800227e-08, 1.98450198e-08,
#         5.67000567e-09, 1.27575128e-08, 1.41750142e-09, 7.08750709e-09,
#         7.08750709e-09, 8.50500851e-09, 1.27575128e-08, 9.92250992e-09,
#         0.00000000e+00, 1.97032697e-07]),
#  array([      0.        ,   66666.66666667,  133333.33333333,
#          200000.        ,  266666.66666667,  333333.33333333,
#          400000.        ,  466666.66666667,  533333.33333333,
#          600000.        ,  666666.66666667,  733333.33333333,
#          800000.        ,  866666.66666667,  933333.33333333,
#         1000000.        , 1066666.66666667, 1133333.33333333,
# ...

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here
plt.figure(figsize=(10, 8))
sb.boxplot(x=df.Age, data=df)
plt.show()

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here

plt.figure(figsize=(10, 8))
sb.scatterplot(x=df.Age, y=df.WorkWeekHrs, data=df)
plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
plt.figure(figsize=(10,5))
plt.scatter(x=df.WorkWeekHrs, y=df.CodeRevHrs, c='blue', alpha=0.1, s=df.Age*10)
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here
df2 = pd.read_sql('select * from DatabaseWorkedWith', conn)
df2.columns
# Out:
# Index(['Respondent', 'DatabaseWorkedWith'], dtype='object')

# %%
df2.head()
# Out:
#    Respondent DatabaseWorkedWith
# 0           4              MySQL
# 1           4             SQLite
# 2           9           DynamoDB
# 3           9         PostgreSQL
# 4           9             SQLite

# %%
df2.groupby('Respondent').count()
# Out:
#             DatabaseWorkedWith
# Respondent
# 4                            2
# 9                            3
# 13                           4
# 16                           3
# 17                           2
# ...                        ...
# 25136                        1
# 25137                        1
# 25138                        1
# 25141                        2
# 25142                        1
#
# [10945 rows x 1 columns]

# %%
df2[df2['DatabaseWorkedWith'].str.contains('SQL')]
# Out:
#        Respondent    DatabaseWorkedWith
# 0               4                 MySQL
# 1               4                SQLite
# 3               9            PostgreSQL
# 4               9                SQLite
# 8              13                 MySQL
# ...           ...                   ...
# 31369       25136  Microsoft SQL Server
# 31370       25137                 MySQL
# 31371       25138            PostgreSQL
# 31372       25141  Microsoft SQL Server
# 31374       25142            PostgreSQL
#
# [16924 rows x 2 columns]

# %%
df2[df2["DatabaseWorkedWith"].str.contains("MySQL")]
# Out:
#        Respondent DatabaseWorkedWith
# 0               4              MySQL
# 8              13              MySQL
# 11             16              MySQL
# 17             19              MySQL
# 24             22              MySQL
# ...           ...                ...
# 31336       25111              MySQL
# 31342       25120              MySQL
# 31356       25124              MySQL
# 31366       25134              MySQL
# 31370       25137              MySQL
#
# [5469 rows x 2 columns]

# %%
df2.groupby("DatabaseWorkedWith").count()
# Out:
#                       Respondent
# DatabaseWorkedWith
# Cassandra                    397
# Couchbase                    250
# DynamoDB                     831
# Elasticsearch               1954
# Firebase                    1314
# MariaDB                     1709
# Microsoft SQL Server        4110
# MongoDB                     3016
# MySQL                       5469
# Oracle                      1744
# Other(s):                    728
# PostgreSQL                  4097
# Redis                       2508
# SQLite                      3248

# %%
y = pd.DataFrame(df2.groupby('DatabaseWorkedWith').count())
y
# Out:
#                       Respondent
# DatabaseWorkedWith
# Cassandra                    397
# Couchbase                    250
# DynamoDB                     831
# Elasticsearch               1954
# Firebase                    1314
# MariaDB                     1709
# Microsoft SQL Server        4110
# MongoDB                     3016
# MySQL                       5469
# Oracle                      1744
# Other(s):                    728
# PostgreSQL                  4097
# Redis                       2508
# SQLite                      3248

# %%
y.sort_values(by='Respondent', ascending=True)
# Out:
#                       Respondent
# DatabaseWorkedWith
# Couchbase                    250
# Cassandra                    397
# Other(s):                    728
# DynamoDB                     831
# Firebase                    1314
# MariaDB                     1709
# Oracle                      1744
# Elasticsearch               1954
# Redis                       2508
# MongoDB                     3016
# SQLite                      3248
# PostgreSQL                  4097
# Microsoft SQL Server        4110
# MySQL                       5469

# %%
y = y.nlargest(10, 'Respondent')
y.reset_index(inplace=True)
y
# Out:
#      DatabaseWorkedWith  Respondent
# 0                 MySQL        5469
# 1  Microsoft SQL Server        4110
# 2            PostgreSQL        4097
# 3                SQLite        3248
# 4               MongoDB        3016
# 5                 Redis        2508
# 6         Elasticsearch        1954
# 7                Oracle        1744
# 8               MariaDB        1709
# 9              Firebase        1314

# %%
plt.figure(figsize=(10,10))
plt.pie(y.Respondent, labels=['MySql', 'Microsoft SQL Server', 'PostgreSQL', 'SQLite', 'MongoDB', 'Redis', 'Elasticsearch', 'Oracle', 'MariaDB', 'Firebase'],
       autopct='%.2f%%')
plt.title("DataBase Worked With Percentages")
plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here
print(df['WorkWeekHrs'].median())
print(df['CodeRevHrs'].median())
# Out:
# 40.0
# 4.0

# %%
age = df[(df["Age"] >= 30.0) & (df["Age"] <= 35.0)]
age
# Out:
#        index  Respondent                      MainBranch Hobbyist  \
# 5          5          19  I am a developer by profession      Yes
# 11        11          26  I am a developer by profession      Yes
# 12        12          29  I am a developer by profession      Yes
# 18        18          49  I am a developer by profession      Yes
# 22        22          56  I am a developer by profession       No
# ...      ...         ...                             ...      ...
# 11385  11385       25120  I am a developer by profession      Yes
# 11391  11391       25133  I am a developer by profession       No
# 11392  11392       25134  I am a developer by profession      Yes
# 11395  11395       25138  I am a developer by profession      Yes
# 11397  11397       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 5                                                  Never
# ...

# %%
plt.figure(figsize=(15,15))
plt.stackplot(age.WorkWeekHrs, age.CodeRevHrs)
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
age2 = df[(df["Age"] >= 45.0) & (df["Age"] <= 60.0)]
age2.head()
# Out:
#     index  Respondent                      MainBranch Hobbyist  \
# 7       7          22  I am a developer by profession      Yes
# 50     50         111  I am a developer by profession      Yes
# 66     66         144  I am a developer by profession       No
# 75     75         164  I am a developer by profession      Yes
# 93     93         202  I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 7      Less than once per year
# 50                       Never
# 66                       Never
# 75                       Never
# 93  Once a month or more often
#
#                                            OpenSource          Employment  \
# 7   OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 50  The quality of OSS and closed source software ...  Employed full-time
# 66  The quality of OSS and closed source software ...  Employed part-time
# 75  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
i = age2['ConvertedComp']

# %%
i.median()
# Out:
# 100000.0

# %%
age2['ConvertedComp'].plot(figsize=(15,12))
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
df['MainBranch'].value_counts()
i = df['MainBranch'].value_counts()

# %%
plt.figure(figsize=(15,10))
sb.barplot(x=i,y=i.index, orient='h')
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
